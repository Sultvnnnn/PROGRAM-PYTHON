# %% [markdown]
# <a href="https://colab.research.google.com/github/Sultvnnnn/PROGRAM-PYTHON/blob/main/Test_Logic_Membuat_Grading_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import statistics as stat

gradeDict = {}

def enterGrades():
  name = input("Enter the student's Name: ")
  grade = float(input("Enter the student's Grade: "))

  if name in gradeDict:
    gradeDict[name].append(grade)
  else:
    gradeDict[name] = [grade]

  print('\nAdding Grade...')

  print("-" * 20)
  for key, value in gradeDict.items():
    print(f"{key}: {value}")
  print("-" * 20)

def removeStudent():
  name = input("Enter the student's Name: ")

  if name in gradeDict:
    del gradeDict[name]
    print(f"{name} has been removed.")
  else:
    print(f"{name} was not found.")

def studentAverage():
  name = input("Enter the student's Name: ")

  if name in gradeDict:
    grades = gradeDict[name]
    average = stat.mean(grades)
    print(f"{name} has an average grade of {average}.")
  else:
    print(f"{name} was not found.")

def showNameList():
  print("-" * 20)
  for key, value in gradeDict.items():
    print(f"{key}: {value}")
  print("-" * 20)

while True:
  print('''
  Welcome to Grade Central

  [1] - Enter Grades
  [2] - Remove Student
  [3] - Student Average Grades
  [4] - Show Name List
  [5] - Exit
  ''')
  data = input("What would you like to do? (Enter a number): ")

  if data == "1":
    enterGrades()
  elif data == "2":
    removeStudent()
  elif data == "3":
    studentAverage()
  elif data == "4":
    showNameList()
  elif data == "5":
    sys.exit("Exiting Program... See You!")
  else:
    sys.exit('Invalid Input!')
# Out:
#   Welcome to Grade Central
#
#   [1] - Enter Grades
#   [2] - Remove Student
#   [3] - Student Average Grades
#   [4] - Show Name List
#   [5] - Exit
#
# What would you like to do? (Enter a number): 1
# Enter the student's Name: Sultan
# Enter the student's Grade: 90
#
# Adding Grade...
# --------------------
# Sultan: [90.0]
# --------------------
#
#   Welcome to Grade Central
#
#   [1] - Enter Grades
#   [2] - Remove Student
#   [3] - Student Average Grades
#   [4] - Show Name List
#   [5] - Exit
#
# What would you like to do? (Enter a number): 1
# Enter the student's Name: Sultan
# Enter the student's Grade: 78
#
# Adding Grade...
# --------------------
# Sultan: [90.0, 78.0]
# --------------------
#
#   Welcome to Grade Central
#
#   [1] - Enter Grades
#   [2] - Remove Student
#   [3] - Student Average Grades
#   [4] - Show Name List
#   [5] - Exit
#
# What would you like to do? (Enter a number): 1
# Enter the student's Name: Sultan
# Enter the student's Grade: 88
#
# Adding Grade...
# --------------------
# Sultan: [90.0, 78.0, 88.0]
# --------------------
#
#   Welcome to Grade Central
#
#   [1] - Enter Grades
#   [2] - Remove Student
#   [3] - Student Average Grades
#   [4] - Show Name List
#   [5] - Exit
#
# What would you like to do? (Enter a number): 4
# --------------------
# Sultan: [90.0, 78.0, 88.0]
# --------------------
#
#   Welcome to Grade Central
#
#   [1] - Enter Grades
#   [2] - Remove Student
#   [3] - Student Average Grades
#   [4] - Show Name List
#   [5] - Exit
#
# What would you like to do? (Enter a number): 3
# Enter the student's Name: Sultan
# Sultan has an average grade of 85.33333333333333.
#
#   Welcome to Grade Central
#
#   [1] - Enter Grades
#   [2] - Remove Student
#   [3] - Student Average Grades
#   [4] - Show Name List
#   [5] - Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1808382313.py in <cell line: 0>()
#      55   [5] - Exit
#      56   ''')
# ---> 57   data = input("What would you like to do? (Enter a number): ")
#      58
#      59   if data == "1":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
